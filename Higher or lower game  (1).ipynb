# %%
import random

data = [
    {
        "Name": "Cristiano Ronaldo",
        "Profession": "Footballer",
        "Followers": 600,
        "Country": "Portugal"
    },
    {
        "Name": "Lionel Messi",
        "Profession": "Footballer",
        "Followers": 450,
        "Country": "Argentina"
    },
    {
        "Name": "LeBron James",
        "Profession": "Basketball Player",
        "Followers": 100,
        "Country": "USA"
    },
    {
        "Name": "Kim Kardashian",
        "Profession": "TV Personality",
        "Followers": 300,
        "Country": "USA"
    },
    {
        "Name": "Dwayne Johnson",
        "Profession": "Actor",
        "Followers": 250,
        "Country": "USA"
    },
    {
        "Name": "Ariana Grande",
        "Profession": "Singer",
        "Followers": 210,
        "Country": "USA"
    },
    {
        "Name": "Selena Gomez",
        "Profession": "Singer",
        "Followers": 195,
        "Country": "USA"
    },
    {
        "Name": "Neymar Jr.",
        "Profession": "Footballer",
        "Followers": 185,
        "Country": "Brazil"
    },
    {
        "Name": "Kylie Jenner",
        "Profession": "Businesswoman",
        "Followers": 190,
        "Country": "USA"
    },
    {
        "Name": "Taylor Swift",
        "Profession": "Singer",
        "Followers": 175,
        "Country": "USA"
    },
    {
        "Name": "Justin Bieber",
        "Profession": "Singer",
        "Followers": 160,
        "Country": "Canada"
    },
    {
        "Name": "Beyoncé",
        "Profession": "Singer",
        "Followers": 155,
        "Country": "USA"
    },
    {
        "Name": "Billie Eilish",
        "Profession": "Singer",
        "Followers": 140,
        "Country": "USA"
    },
    {
        "Name": "Katy Perry",
        "Profession": "Singer",
        "Followers": 135,
        "Country": "USA"
    },
    {
        "Name": "Shakira",
        "Profession": "Singer",
        "Followers": 125,
        "Country": "Colombia"
    },
    {
        "Name": "Virat Kohli",
        "Profession": "Cricketer",
        "Followers": 130,
        "Country": "India"
    },
    {
        "Name": "Ellen DeGeneres",
        "Profession": "TV Host",
        "Followers": 120,
        "Country": "USA"
    },
    {
        "Name": "Rihanna",
        "Profession": "Singer",
        "Followers": 110,
        "Country": "Barbados"
    },
    {
        "Name": "David Beckham",
        "Profession": "Footballer",
        "Followers": 105,
        "Country": "UK"
    },
    {
        "Name": "Shawn Mendes",
        "Profession": "Singer",
        "Followers": 100,
        "Country": "Canada"
    }
]
score=0
t=0
while t==0:
    a=random.choice(data)
    b=random.choice(data)
    while a==b:
        b=random.choice(data)
    
    print(f"Compare A: {a['Name']} {a['Profession']} from {a['Country']}")
    print(f"Against B: {b['Name']} {b['Profession']} from {b['Country']}")
    ch=input("Which has more followers Enter your choice A/B").upper()
    if ch=="A":
        
        if a["Followers"]>b["Followers"]:
            print("Your are right")
            score+=1
            print("Your current score is ",score)
        else:
            print("Wrong")
            print(f"Your Final Score is {score}")
            t=1
            break
    elif ch=="B":
        if b["Followers"]>a["Followers"]:
            print("Your are right")
            print("Your current score is ",score)
            score+=1
        else:
            print("Wrong")
            print(f"Your Final Score is {score}")
            t=1
            break
print("Game over")
# Out:
# Compare A: Cristiano Ronaldo Footballer from Portugal
# Against B: Virat Kohli Cricketer from India
# Which has more followers Enter your choice A/B A
# Your are right
# Your current score is  1
# Compare A: Justin Bieber Singer from Canada
# Against B: Beyoncé Singer from USA
# Which has more followers Enter your choice A/B b
# Wrong
# Your Final Score is 1
# Game over
